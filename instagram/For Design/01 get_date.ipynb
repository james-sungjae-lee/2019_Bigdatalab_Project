# %%
import pandas as pd
import numpy as np

fallfile = 'fallfashion_5000_rawdata-Copy1.json'

fall_df = pd.read_json(fallfile)

# %%
fall_date = fall_df['date'].sort_values()

# %%
4981-781
# Out:
# 4200

# %%
fall_df.loc[746]

# %%
fall_date
# Out:
# 746    2012-11-23 00:05:26
# 1743   2012-11-25 18:12:20
# 2830   2013-09-24 19:31:50
# 2938   2013-10-09 15:03:52
# 671    2013-10-17 14:30:38
# 1832   2013-10-17 15:08:19
# 1621   2013-10-18 02:45:51
# 400    2013-10-29 15:23:22
# 1314   2013-11-05 19:51:19
# 1836   2013-11-07 18:38:27
# 89     2014-03-18 04:13:06
# 2075   2014-04-15 19:33:06
# 4224   2014-12-20 08:45:00
# 157    2015-01-01 20:43:25
# 1651   2015-07-06 00:27:02
# 1920   2015-07-07 01:33:21
# 2567   2015-07-10 00:42:08
# 2894   2015-07-18 23:08:44
# 4043   2015-07-28 03:57:34
# 3487   2015-10-08 19:08:35
# 1981   2016-01-15 18:29:00
# 3140   2016-07-05 19:41:50
# 2473   2016-07-24 21:24:56
# 2027   2016-10-05 04:33:25
# 1794   2016-11-04 12:38:42
# 2917   2016-12-21 20:51:22
# 1713   2017-06-08 22:25:25
# 2158   2017-06-15 12:40:40
# 2079   2017-08-03 17:29:13
# 2888   2017-09-05 05:24:42
#                ...
# 4760                   NaT
# 4763                   NaT
# 4768                   NaT
# ...

# %% [markdown]
# fallfashion 가장 마지막 게시물 2019-01-31
#
# 첫 게시물 2012-11-23

# %%
fall_not_date = fall_date.iloc[4200:]

# %%
fall_not_date_list = fall_not_date.index

# %%
fall_not_date_list
# Out:
# Int64Index([   5,    6,   26,   36,   38,   55,   61,   66,   67,   72,
#             ...
#             4882, 4890, 4898, 4899, 4922, 4929, 4940, 4949, 4968, 4971],
#            dtype='int64', length=781)

# %%
spring_file = 'spring_5k_rawdata-Copy1.json'

spring_df = pd.read_json(spring_file)

# %%
spring_df
# Out:
#      comments                date  \
# 0           0                 NaT
# 1           0 2019-01-25 16:34:32
# 2           1 2019-01-29 08:32:24
# 3           3 2019-01-31 03:21:45
# 4           0 2019-01-27 15:54:26
# 5          17 2019-01-26 23:47:18
# 6          12 2019-01-28 03:28:30
# 7           2 2019-01-26 01:33:30
# 8           0                 NaT
# 9           1 2019-01-29 05:40:00
# 10          1 2019-01-26 21:23:53
# 11          0                 NaT
# 12         16 2019-01-29 03:48:36
# 13          1 2019-01-26 14:04:48
# 14          0 2019-01-30 16:24:17
# 15          1 2019-01-26 11:26:39
# 16          2 2019-01-30 13:16:33
# 17          0 2019-01-27 15:31:14
# 18          2 2019-01-28 15:03:12
# 19          0                 NaT
# 20          2 2019-01-26 19:00:47
# 21          4 2019-01-25 01:01:21
# 22          2 2019-01-30 11:36:45
# 23          2 2019-01-27 01:38:31
# 24          0 2019-01-29 08:50:52
# 25          0 2019-01-30 08:35:20
# ...

# %%
spring_df.iloc[500]['imagelinks']
# Out:
# ['https://scontent-icn1-1.cdninstagram.com/vp/c6046414d3c5997b9ff533f438bc4e46/5CE946CA/t51.2885-15/e35/49388163_616246265496278_7076339136993843980_n.jpg?_nc_ht=scontent-icn1-1.cdninstagram.com']

# %%
spring_date = spring_df['date'].sort_values()

# %%
spring_date
# Out:
# 3069   2016-04-13 10:50:16
# 3631   2016-06-12 18:36:03
# 3102   2016-10-07 00:38:30
# 4122   2017-02-23 02:28:21
# 1296   2017-05-01 03:43:30
# 599    2017-06-15 01:29:25
# 1605   2017-07-12 10:03:30
# 2579   2017-07-27 03:40:22
# 4035   2017-10-30 23:52:00
# 2776   2017-11-25 05:24:42
# 4973   2018-03-08 16:47:25
# 4539   2018-03-28 06:38:33
# 2589   2018-04-10 11:12:23
# 827    2018-04-29 01:07:58
# 1302   2018-06-13 06:32:13
# 168    2018-06-17 15:32:49
# 3143   2018-06-24 06:26:40
# 4336   2018-07-17 00:28:49
# 2795   2018-07-18 22:27:11
# 2469   2018-07-18 22:33:32
# 4168   2018-07-25 07:53:41
# 3623   2018-08-04 22:13:32
# 1865   2018-08-07 18:08:56
# 2309   2018-08-15 02:24:57
# 4136   2018-09-03 01:34:25
# 1199   2018-10-08 15:10:34
# 189    2018-10-16 03:14:29
# 1327   2018-10-19 14:22:00
# 1111   2018-11-08 14:10:21
# 1700   2018-12-15 10:38:19
#                ...
# 4763                   NaT
# 4764                   NaT
# 4765                   NaT
# ...

# %%
spring_date.isnull().sum()
# Out:
# 702

# %%
spring_date.iloc[4297]
# Out:
# Timestamp('2019-01-31 12:44:10')

# %% [markdown]
# spring 첫 게시물 : 2016-04-13
#
# 마지막 게시물 ㅣ 2019-01-31

# %%
spring_not_date = spring_date.iloc[4298:]

# %%
spring_not_date_list = spring_not_date.index

# %%
summer_file = 'summer_5k_rawdata-Copy1.json'

summer_df = pd.read_json(summer_file)

# %%
summer_date = summer_df['date'].sort_values()

# %%
summer_date
# Out:
# 1390   2014-08-08 11:44:03
# 3626   2016-05-14 23:57:15
# 2609   2016-05-24 09:35:59
# 2296   2016-06-07 10:50:53
# 2375   2016-07-16 18:04:15
# 4151   2016-08-27 21:23:24
# 3582   2016-08-28 18:42:48
# 1715   2016-09-01 10:19:40
# 1062   2016-10-24 14:24:12
# 3017   2017-06-02 16:16:32
# 3267   2017-06-04 23:27:28
# 3110   2017-06-06 19:54:35
# 2848   2017-06-16 13:57:03
# 1753   2017-06-25 18:46:15
# 3186   2017-07-02 20:05:31
# 1134   2017-07-18 04:32:02
# 503    2017-08-05 10:28:39
# 2933   2017-08-09 16:03:47
# 2327   2017-09-01 18:17:34
# 4816   2017-11-19 23:03:48
# 3630   2017-12-03 17:54:39
# 4823   2018-02-07 15:49:52
# 917    2018-02-17 06:52:22
# 4145   2018-02-19 19:29:21
# 4584   2018-02-19 19:33:08
# 599    2018-03-09 14:52:25
# 3953   2018-03-09 14:53:27
# 2133   2018-03-11 02:18:03
# 2301   2018-03-13 15:52:38
# 1027   2018-03-18 16:06:21
#                ...
# 4799                   NaT
# 4803                   NaT
# 4825                   NaT
# ...

# %%
summer_date.isnull().sum()
# Out:
# 650

# %%
summer_date.iloc[4349]
# Out:
# Timestamp('2019-01-31 08:59:33')

# %% [markdown]
# summer 첫 게시물 : 2014-08-08
# 마지막 게시물 : 2019-01-31

# %%
winter_file = 'winter_5k_rawdata-Copy1.json'
winter_df = pd.read_json(winter_file)

# %%
winter_df
# Out:
#         comments                date  \
# 0              5 2019-01-29 18:18:56
# 1              0 2019-01-30 13:23:35
# 2              2 2019-01-30 20:50:33
# 3              5 2019-01-30 18:03:03
# 4            170 2019-01-29 18:38:25
# 5              5 2019-01-30 17:44:08
# 6              4 2019-01-29 22:30:41
# 7              1 2019-01-30 22:34:32
# 8             26 2019-01-30 21:17:45
# 9              0                 NaT
# 10             0 2019-01-30 23:41:02
# 11             0 2019-01-30 16:44:04
# 12             2 2019-01-29 15:22:24
# 13             4 2019-01-31 00:12:45
# 14             2 2019-01-30 11:22:12
# 15             0 2019-01-30 03:39:50
# 16             0                 NaT
# 17             0 2019-01-30 14:30:02
# 18             0                 NaT
# 19            10 2019-01-30 02:42:18
# 20             5 2019-01-29 19:12:02
# 21             1 2019-01-31 00:16:23
# 22             3 2019-01-30 02:23:21
# 23             0 2019-01-30 01:35:58
# ...

# %%
winter_date = winter_df['date'].sort_values()

# %%
winter_date
# Out:
# 2285   2015-01-27 18:30:15
# 480    2015-07-05 15:02:57
# 2803   2015-07-06 00:27:02
# 3257   2015-07-07 01:33:21
# 4501   2015-07-10 00:42:08
# 2946   2015-07-19 04:25:02
# 4312   2015-07-25 20:45:41
# 4914   2016-02-19 09:26:01
# 1293   2016-12-05 00:34:14
# 4293   2017-01-18 10:46:21
# 2897   2017-03-04 21:55:08
# 1100   2017-06-30 19:53:20
# 3167   2018-01-14 14:52:30
# 1185   2018-01-20 22:36:20
# 3585   2018-01-26 23:11:23
# 618    2018-02-04 15:51:19
# 4865   2018-02-10 19:17:27
# 541    2018-02-13 14:28:27
# 718    2018-03-04 16:42:55
# 1449   2018-07-23 15:42:08
# 1178   2018-08-24 13:45:52
# 2364   2018-09-24 21:52:54
# 4495   2018-09-24 22:50:41
# 3331   2018-09-25 12:52:20
# 708    2018-09-28 19:47:48
# 623    2018-10-04 17:05:55
# 286    2018-10-06 00:23:01
# 3752   2018-10-11 12:25:46
# 149    2018-10-13 13:03:21
# 1364   2018-10-23 21:59:07
#                ...
# 4764                   NaT
# 4772                   NaT
# 4775                   NaT
# ...

# %%
winter_date.isnull().sum()
# Out:
# 722

# %%
winter_date.iloc[4277]
# Out:
# Timestamp('2019-01-31 04:04:54')

# %% [markdown]
# winter 첫 게시물 : 2015 - 01 - 27
#
# 마지막 게시물 : 2019-01-31
