# %%
import pandas as pd
df = pd.read_json('seoulfashion_rawdata.json')
df.head()
# Out:
#   comments                                           contents  \
# 0        0  KOREAN FASHION NEW COLLECTION❤HIGH &amp PREMIU...
# 1        1  ∆ 一套三條 可每條分拆 necklace 239HKD———————————查詢\購買方法...
# 2        0
# 3        0
# 4        0  一月韓國連線新品陸續上架中！ 大家快來把新年新衣準備好吧！東大門即將換季，買冬衣的機會不多囉...
#
#                  date      find_tag  \
# 0 2019-01-09 06:07:14  seoulfashion
# 1 2019-01-08 07:02:45  seoulfashion
# 2 2019-01-13 22:32:43  seoulfashion
# 3                 NaT  seoulfashion
# 4 2019-01-11 06:53:26  seoulfashion
#
#                                             hashtags           id  \
# 0  [madeinkorea, stylekorea, dresskorea, kstyle, ...  BsZzV4en04_
# 1  [freshstyle, hkcafe, travelphotography, outdoo...  BsXU5rIhBkV
# 2  [color, moon, russia, korean, 2019, gray, inst...  Bsl3TSYgQXv
# 3  [seoulfashion, seoulstyle, koreanstyle, korean...  Bsib1Z2Fop_
# 4  [針織, 毛衣, cantwait, 韓國連線, seoulfashion, 裙, 飾品, ...  BsfCOAWn2Mu
#
#                                           imagelinks likes  \
# 0  [https://scontent-icn1-1.cdninstagram.com/vp/e...     8
# 1  [https://scontent-icn1-1.cdninstagram.com/vp/9...    43
# 2  [https://scontent-icn1-1.cdninstagram.com/vp/1...    59
# 3  [https://scontent-icn1-1.cdninstagram.com/vp/5...     0
# 4  [https://scontent-icn1-1.cdninstagram.com/vp/f...    24
#
#              location                username
# 0                                  afrshop_id
# 1           Hong Kong              chablis_st
# 2      Moscow, Russia               i.migmoon
# 3  Seoul, South Korea  feelfreethailand_seoul
# 4                                  sansokorea

# %%
base_df = df[['id', 'username', 'hashtags']]

# %%
base_df.head()
# Out:
#             id                username  \
# 0  BsZzV4en04_              afrshop_id
# 1  BsXU5rIhBkV              chablis_st
# 2  Bsl3TSYgQXv               i.migmoon
# 3  Bsib1Z2Fop_  feelfreethailand_seoul
# 4  BsfCOAWn2Mu              sansokorea
#
#                                             hashtags
# 0  [madeinkorea, stylekorea, dresskorea, kstyle, ...
# 1  [freshstyle, hkcafe, travelphotography, outdoo...
# 2  [color, moon, russia, korean, 2019, gray, inst...
# 3  [seoulfashion, seoulstyle, koreanstyle, korean...
# 4  [針織, 毛衣, cantwait, 韓國連線, seoulfashion, 裙, 飾品, ...

# %%
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835 entries, 0 to 1834
# Data columns (total 3 columns):
# id          1835 non-null object
# username    1835 non-null object
# hashtags    1835 non-null object
# dtypes: object(3)
# memory usage: 43.1+ KB

# %%
base_df[['id', 'username']].describe()
# Out:
#                  id    username
# count          1835        1835
# unique         1835         269
# top     BsfFgkagrH_  afrshop_id
# freq              1         379

# %%
groupby_df = base_df.groupby('username').agg({'hashtags': 'sum'})

# %%
print(base_df.info())
base_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835 entries, 0 to 1834
# Data columns (total 3 columns):
# id          1835 non-null object
# username    1835 non-null object
# hashtags    1835 non-null object
# dtypes: object(3)
# memory usage: 43.1+ KB
# None
#             id                username  \
# 0  BsZzV4en04_              afrshop_id
# 1  BsXU5rIhBkV              chablis_st
# 2  Bsl3TSYgQXv               i.migmoon
# 3  Bsib1Z2Fop_  feelfreethailand_seoul
# 4  BsfCOAWn2Mu              sansokorea
#
#                                             hashtags
# 0  [madeinkorea, stylekorea, dresskorea, kstyle, ...
# 1  [freshstyle, hkcafe, travelphotography, outdoo...
# 2  [color, moon, russia, korean, 2019, gray, inst...
# 3  [seoulfashion, seoulstyle, koreanstyle, korean...
# 4  [針織, 毛衣, cantwait, 韓國連線, seoulfashion, 裙, 飾品, ...

# %%
print(groupby_df.info())
groupby_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 269 entries,  to zptrara
# Data columns (total 1 columns):
# hashtags    269 non-null object
# dtypes: object(1)
# memory usage: 4.2+ KB
# None
#                                                            hashtags
# username
#                   [арт, like, follow, lineart, подписка, kpop, f...
# 158.store         [เดรส, jetsetbrand, pinkbypink, madeoffabric, ...
# 1percentofna      [時尚, cutegirl, modelpost, koreatrip, lifeisgoo...
# 71sunny           [seoulfashionweek, koreanstyle, seoulfashion, ...
# 9deelita_beauty   [พรีออเดอร์เกาหลี, siambrandname, kloset, kore...
# _6.moons_                                                        []
# _hyun.jae_0309    [kfashionstyle, seoulfashion, ulzzanggirl, ulz...
# _k0reanfash1on_   [seoulfashion, ulzzangfashion, koreanstyles, r...
# _korean.beauty__  [goals, koreanoutfit, koreanbeauty, ulzzangfas...
# a.bell_daily                                                     []

# %%
remove_test = groupby_df[groupby_df.astype(str)['hashtags'] != '[]']

# %%
print(remove_test.info())
remove_test.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251 entries,  to zptrara
# Data columns (total 1 columns):
# hashtags    251 non-null object
# dtypes: object(1)
# memory usage: 3.9+ KB
# None
#                                                            hashtags
# username
#                   [арт, like, follow, lineart, подписка, kpop, f...
# 158.store         [เดรส, jetsetbrand, pinkbypink, madeoffabric, ...
# 1percentofna      [時尚, cutegirl, modelpost, koreatrip, lifeisgoo...
# 71sunny           [seoulfashionweek, koreanstyle, seoulfashion, ...
# 9deelita_beauty   [พรีออเดอร์เกาหลี, siambrandname, kloset, kore...
# _hyun.jae_0309    [kfashionstyle, seoulfashion, ulzzanggirl, ulz...
# _k0reanfash1on_   [seoulfashion, ulzzangfashion, koreanstyles, r...
# _korean.beauty__  [goals, koreanoutfit, koreanbeauty, ulzzangfas...
# aammiirr1017      [sophocles, i, thirdeyethirst, onnabugeisha, p...
# adekuver          [토니마티체브스키, adekuver, 좋아요반사, adkv, 아데쿠베, matice...

# %%
remove_test = remove_test[1:]

# %%
remove_test.head(3)
# Out:
#                                                        hashtags
# username
# 158.store     [เดรส, jetsetbrand, pinkbypink, madeoffabric, ...
# 1percentofna  [時尚, cutegirl, modelpost, koreatrip, lifeisgoo...
# 71sunny       [seoulfashionweek, koreanstyle, seoulfashion, ...

# %%
tag_dict = {}

# %%
tag_dict['test'] = 1

# %%
tag_dict
# Out:
# {'test': 1}

# %%
tag_dict['test2'] = 2

# %%
tag_dict
# Out:
# {'test': 1, 'test2': 2}

# %%
tag_dict['test'] = tag_dict['test'] + 1

# %%
tag_dict
# Out:
# {'test': 2, 'test2': 2}

# %%
tag_dict.clear()
tag_dict
# Out:
# {}

# %%
test_dict1 = {}

# %%
check = test_dict1.get('a')
if check == None:
    print('a is not here')
# Out:
# a is not here

# %%
if word in hash_map:
                hash_map[word] = hash_map[word] + 1
            else:
                hash_map[word] = 1

# %%
test_dict = {}
test_list = [['A', 'B', 'C'], ['A', 'B'], ['A']]
for one_list in test_list:
    for word in one_list:
        if word in test_dict:
            test_dict[word] = test_dict[word] + 1
        else:
            test_dict[word] = 1
print(test_dict)
# Out:
# {'A': 3, 'B': 2, 'C': 1}

# %%
tag_dict = {}
for index, row in remove_test.iterrows():
    for tag in row['hashtags']:
        if tag in tag_dict:
            tag_dict[tag] = tag_dict[tag] + 1
        else:
            tag_dict[tag] = 1

# %%
dict(list(tag_dict.items())[:10])
# Out:
# {'เดรส': 7,
#  'jetsetbrand': 1,
#  'pinkbypink': 1,
#  'madeoffabric': 7,
#  'paing': 5,
#  'เสื้อผ้าแฟชั่นเกาหลี': 1,
#  'flat2112': 7,
#  'zara': 35,
#  'ซัมเมอร์': 1,
#  'เดรสยาว': 1}

# %%
sort_dict = sorted(tag_dict.items(), key=lambda kv: kv[1])

# %%
sort_dict[-30:]
# Out:
# [('importkorea', 379),
#  ('highquality', 379),
#  ('southkoreafashion', 379),
#  ('koreanaccessories', 379),
#  ('koreandress', 379),
#  ('firsthandkorea', 379),
#  ('aksesoriskorea', 379),
#  ('pofirsthandkorea', 379),
#  ('pokoreafirsthand', 379),
#  ('po2019afrshop_id', 379),
#  ('pokorea', 379),
#  ('pojan2019afrshop_id', 379),
#  ('koreantee', 379),
#  ('koreanblouse', 379),
#  ('koreatrend', 379),
#  ('korea', 382),
#  ('dresskorea', 385),
#  ('fashionkorea', 388),
#  ('seoul', 447),
#  ('style', 452),
#  ('kstyle', 463),
#  ('ulzzangfashion', 487),
#  ('ulzzang', 505),
#  ('kfashion', 617),
#  ('koreafashion', 683),
#  ('preorderkorea', 683),
#  ('madeinkorea', 742),
#  ('koreanfashion', 826),
#  ('koreanstyle', 828),
#  ('seoulfashion', 1696)]

# %%
type(sort_dict)
## this is list of tuple
# Out:
# list

# %%
## list of tuple -> pandas dataframe
top100 = pd.DataFrame(sort_dict[-100:], columns=['Tag', 'Freq'])
top100.head()
# Out:
#               Tag  Freq
# 0  แฟชั่นหน้าหนาว    79
# 1       เสื้อโค้ท    79
# 2        เสื้อสูท    79
# 3             fur    79
# 4       สเวตเตอร์    79

# %%
top100.sort_values(by = 'Freq', ascending = False)
# Out:
#                     Tag  Freq
# 99         seoulfashion  1696
# 98          koreanstyle   828
# 97        koreanfashion   826
# 96          madeinkorea   742
# 95        preorderkorea   683
# 94         koreafashion   683
# 93             kfashion   617
# 92              ulzzang   505
# 91       ulzzangfashion   487
# 90               kstyle   463
# 89                style   452
# 88                seoul   447
# 87         fashionkorea   388
# 86           dresskorea   385
# 85                korea   382
# 75       firsthandkorea   379
# 68           stylekorea   379
# 69            bajukorea   379
# 70          importkorea   379
# 71          highquality   379
# 72    southkoreafashion   379
# 73    koreanaccessories   379
# 74          koreandress   379
# 76       aksesoriskorea   379
# 77     pofirsthandkorea   379
# 78     pokoreafirsthand   379
# 79     po2019afrshop_id   379
# 80              pokorea   379
# 81  pojan2019afrshop_id   379
# 82            koreantee   379
# ..                  ...   ...
# 29           instadaily    98
# 28           ulzzangboy    96
# 27          ulzzanggirl    95
# 26               winter    91
# 25           seoulkorea    90
# 24                   韓國    88
# 23            dailylook    87
# 22       outfitoftheday    86
# 21          เสื้อไหมพรม    85
# 20         koreanoutfit    85
# 19                igers    84
# 18             韓国ファッション    83
# 17                 coat    83
# 16            instalove    82
# 15            เสื้อคลุม    82
# 14         bestoftheday    81
# 13         instagirlshk    80
# 12           fallwinter    80
# 11              hkigers    80
# 10              sweater    80
# 3                   fur    79
# 5              cardigan    79
# 2              เสื้อสูท    79
# 4             สเวตเตอร์    79
# 1             เสื้อโค้ท    79
# 6       เสื้อโค้ทเกาหลี    79
# 7           โอเวอร์โค้ท    79
# 8                  knit    79
# 9             ส่งฟรีค่ะ    79
# 0        แฟชั่นหน้าหนาว    79
#
# [100 rows x 2 columns]

# %%
df_nodes = top100.sort_values(by = 'Freq', ascending = False)

# %%
# !pip install networkx
# Out:
# Collecting networkx
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.6/site-packages (from networkx) (4.3.0)
# Installing collected packages: networkx
# Successfully installed networkx-2.2

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/71/07/16d781df15be30df4acfd536c479268f1208b2dfbc91e9ca5d92c9caf673/matplotlib-3.0.2-cp36-cp36m-manylinux1_x86_64.whl (12.9MB)
#     100% |████████████████████████████████| 12.9MB 3.6MB/s eta 0:00:01   14% |████▌                           | 1.8MB 25.8MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from matplotlib) (1.16.0)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/69/a7/88719d132b18300b4369fbffa741841cfd36d1e637e1990f27929945b538/kiwisolver-1.0.1-cp36-cp36m-manylinux1_x86_64.whl (949kB)
#     100% |████████████████████████████████| 952kB 14.0MB/s ta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib) (2.7.5)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/de/0a/001be530836743d8be6c2d85069f46fecf84ac6c18c7f5fb8125ee11d854/pyparsing-2.3.1-py2.py3-none-any.whl (61kB)
#     100% |████████████████████████████████| 71kB 17.4MB/s ta 0:00:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib) (40.6.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib) (1.12.0)
# Installing collected packages: kiwisolver, cycler, pyparsing, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.0.1 matplotlib-3.0.2 pyparsing-2.3.1

# %%
df_nodes.head()
# Out:
#               Tag  Freq
# 99   seoulfashion  1696
# 98    koreanstyle   828
# 97  koreanfashion   826
# 96    madeinkorea   742
# 95  preorderkorea   683

# %%
## Group num with Random integer
import numpy as np
df_nodes['Group'] = np.random.randint(1, 14, df_nodes.shape[0])

# %%
df_nodes.head()
# Out:
#               Tag  Freq  Group
# 99   seoulfashion  1696      5
# 98    koreanstyle   828     12
# 97  koreanfashion   826      6
# 96    madeinkorea   742      3
# 95  preorderkorea   683     10

# %%
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

G = nx.Graph(day="Stackoverflow")

for index, row in df_nodes.iterrows():
    G.add_node(row['Tag'], group=row['Group'], nodesize=row['Freq'])
    
color_map = {1:'#f09494', 2:'#eebcbc', 3:'#72bbd0', 4:'#91f0a1', 5:'#629fff', 6:'#bcc2f2',  
             7:'#eebcbc', 8:'#f1f0c0', 9:'#d2ffe7', 10:'#caf3a6', 11:'#ffdf55', 12:'#ef77aa', 
             13:'#d6dcff', 14:'#d2f5f0'} 

plt.figure(figsize=(25,25))
options = {
    'edge_color': '#FFDEA2',
    'width': 1,
    'with_labels': True,
    'font_weight': 'regular',
}

colors = [color_map[G.node[node]['group']] for node in G]
sizes = [G.node[node]['nodesize']*10 for node in G]

"""
Using the spring layout : 
- k controls the distance between the nodes and varies between 0 and 1
- iterations is the number of times simulated annealing is run
default k=0.1 and iterations=50
"""
nx.draw(G, node_color=colors, node_size=sizes, pos=nx.spring_layout(G, k=0.25, iterations=50), **options)
ax = plt.gca()
ax.collections[0].set_edgecolor("#555555") 
plt.show()
