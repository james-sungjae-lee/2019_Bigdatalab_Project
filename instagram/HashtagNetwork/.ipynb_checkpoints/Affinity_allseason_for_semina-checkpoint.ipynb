# %% [markdown]
# # Rawdata preprocessing

# %%
import pandas as pd
import numpy as np


filename = 'allseason_20k_rawdata.json'

allseason = pd.read_json(filename)

# %%
base_df = allseason[['id','username','hashtags']]
#base_df.head()
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19981 entries, 0 to 19980
# Data columns (total 3 columns):
# id          19981 non-null object
# username    19981 non-null object
# hashtags    19981 non-null object
# dtypes: object(3)
# memory usage: 468.4+ KB

# %%
base_df.head()
# Out:
#             id                  username  \
# 0  BtOm-dkHn5v              petraruzicka
# 1  BtQp-IfHkzq                sonesta007
# 2  BtRdH3UBQ6i               heofficial_
# 3  BtRJG92g_CG  thefashionbeautygalleria
# 4  BtOpNQpApMI          fashionablyfifty
#
#                                             hashtags
# 0  [sport, travelling, winterfashion, cestovani, ...
# 1  [instagood, instastyle, fashionblog, fashionbl...
# 2  [london, like4like, corduroy, beanie, ootd, uk...
# 3                                                 []
# 4  [styleover50, chiberia, styleisforlife, thrift...

# %%
base_df.index = base_df['username']

# %%
base_df = base_df.drop(columns=['username'])

# %%
base_df = base_df.drop(columns=['id'])

# %%
base_df.head()
# Out:
#                                                                    hashtags
# username
# petraruzicka              [sport, travelling, winterfashion, cestovani, ...
# sonesta007                [instagood, instastyle, fashionblog, fashionbl...
# heofficial_               [london, like4like, corduroy, beanie, ootd, uk...
# thefashionbeautygalleria                                                 []
# fashionablyfifty          [styleover50, chiberia, styleisforlife, thrift...

# %%
# 잘못된 데이터들을 처리해줍니다.
fashion_df = base_df[base_df.astype(str)['hashtags'] != '[]']
fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17644 entries, petraruzicka to raineydaerunway
# Data columns (total 1 columns):
# hashtags    17644 non-null object
# dtypes: object(1)
# memory usage: 275.7+ KB

# %%
fashion_df.head()
# Out:
#                                                                  hashtags
# username
# petraruzicka            [sport, travelling, winterfashion, cestovani, ...
# sonesta007              [instagood, instastyle, fashionblog, fashionbl...
# heofficial_             [london, like4like, corduroy, beanie, ootd, uk...
# fashionablyfifty        [styleover50, chiberia, styleisforlife, thrift...
# mariadelosangeles_mdla  [lasvegas, style, mariadelosangeles_mdla, inst...

# %%
fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17644 entries, petraruzicka to raineydaerunway
# Data columns (total 1 columns):
# hashtags    17644 non-null object
# dtypes: object(1)
# memory usage: 275.7+ KB

# %%
# 태그가 몇번 나왔는지 세어주는 함수입니다.
def getTagsDict(df):
    tag_dict = {}
    
    for index, row in df.iterrows():
        for tag in row['hashtags']:
            if tag in tag_dict:
                tag_dict[tag] = tag_dict[tag] + 1
            else:
                tag_dict[tag] = 1
                
    sort_dict = sorted(tag_dict.items(), key=lambda kv: kv[1])
    return sort_dict

sort_dict = getTagsDict(fashion_df)

# %%
sort_dict[-10:]
# Out:
# [('fashionista', 2276),
#  ('instafashion', 2587),
#  ('fashionblogger', 3139),
#  ('ootd', 4257),
#  ('style', 4389),
#  ('fallfashion', 4400),
#  ('summerfashion', 4822),
#  ('springfashion', 4845),
#  ('winterfashion', 6016),
#  ('fashion', 6847)]

# %%
# 중복을 제거해줍니다. (한 글에 동일한 태그 여러 번)

tag_df = list(fashion_df['hashtags'])

for i in range(len(tag_df)):
#     if "fashion" in tag_df[i] == False:
#         print(tag_df[i])
    tag_df[i] = list(set(tag_df[i]))

fashion_df['hashtags'] = tag_df
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17644 entries, petraruzicka to raineydaerunway
# Data columns (total 1 columns):
# hashtags    17644 non-null object
# dtypes: object(1)
# memory usage: 275.7+ KB

# %%
fashion_dict = getTagsDict(fashion_df)
print(fashion_dict[-10:])
print(fashion_df.info())
# Out:
# [('fashionista', 2276), ('instafashion', 2587), ('fashionblogger', 3139), ('ootd', 4250), ('style', 4389), ('fallfashion', 4400), ('summerfashion', 4822), ('springfashion', 4845), ('winterfashion', 6016), ('fashion', 6847)]
# <class 'pandas.core.frame.DataFrame'>
# Index: 17644 entries, petraruzicka to raineydaerunway
# Data columns (total 1 columns):
# hashtags    17644 non-null object
# dtypes: object(1)
# memory usage: 275.7+ KB
# None

# %%
fashion_dict[-30:]
# Out:
# [('fashionaddict', 929),
#  ('model', 948),
#  ('spring', 1059),
#  ('outfitoftheday', 1104),
#  ('boutique', 1122),
#  ('trendy', 1123),
#  ('onlineboutique', 1132),
#  ('instastyle', 1172),
#  ('sale', 1183),
#  ('instagood', 1204),
#  ('stylish', 1323),
#  ('styleblogger', 1336),
#  ('love', 1337),
#  ('summer', 1392),
#  ('fashionpost', 1413),
#  ('streetstyle', 1529),
#  ('onlineshopping', 1568),
#  ('womensfashion', 1592),
#  ('shopping', 1601),
#  ('winter', 1616),
#  ('fashionista', 2276),
#  ('instafashion', 2587),
#  ('fashionblogger', 3139),
#  ('ootd', 4250),
#  ('style', 4389),
#  ('fallfashion', 4400),
#  ('summerfashion', 4822),
#  ('springfashion', 4845),
#  ('winterfashion', 6016),
#  ('fashion', 6847)]

# %%
len(fashion_dict)
# 태그의 종류가 5만개입니다.
# Out:
# 56815

# %%
# fashion이 앞에 들어간 태그를 삭제해줍니다.
# 이유는 fashioninsta, fashionable ... 등의 태그는 무의미 하다고 생각하기 때문입니다.
# 하지만 fashionjacket 등의 태그들을 놓칠 수 있습니다.
# blog가 앞에 들어간 태그도 삭제해줍니다. 

for key in fashion_dict:
    tag = key[0]
    index_fashion = tag.find('fashion')
    index_blog = tag.find('blog')
    if index_fashion > -1 and index_fashion < 1:
        fashion_dict.remove(key)
    if index_blog > -1 and index_blog < 1:
        fashion_dict.remove(key)

# %%
len(fashion_dict)
# Out:
# 55972

# %%
fashion_dict = fashion_dict[-200:]
# 가장 빈도수가 높은 태그 200개만 얻어냅니다.

# %%
print(len(fashion_dict))
# Out:
# 200

# %%
tag_list = []
for i in fashion_dict:
    tag_list.append(i[0])

print(tag_list)
print(len(tag_list))
# Out:
# ['like', 'instapic', 'hair', 'jewelrygram', 'classy', 'fblogger', 'vintagestyle', 'inspo', 'sexy', 'holiday', 'outfitpost', 'hijabfashion', 'earrings', 'babyfashion', 'fun', 'ss19', 'summerdress', 'photographer', 'jewelrydesign', 'instyle', 'beachwear', 'girls', 'shoppingaddict', 'sun', 'black', 'coat', 'newcollection', 'igstyle', 'bikini', 'menstyle', 'sales', 'modeling', 'me', 'pink', 'fallstyle', 'boho', 'usa', 'men', 'womensclothing', 'plussize', 'sweater', 'shoponline', 'boots', 'shoppingonline', 'ontrend', 'menfashion', 'bohostyle', 'ootn', 'thatsdarling', 'lifestyleblogger', 'floral', 'look', 'swimwear', 'sustainablefashion', 'denim', 'mystyle', 'girlboss', 'selfie', 'art', 'vintagefashion', 'trendsetter', 'jewelryaddict', 'design', 'mensstyle', 'plussizefashion', 'followme', 'women', 'currentlywearing', 'winterwonderland', 'musthave', 'freeshipping', 'cold', 'fitness', 'happy', 'photoshoot', 'instalike', 'outfits', 'trends', '2019', 'nyc', 'inspiration', 'nature', 'sweaterweather', 'handmadejewelry', 'chic', 'newyork', 'makeup', 'styleinspiration', 'stylegram', 'wiw', 'pretty', 'influencer', 'girl', 'wiwt', 'smallbusiness', 'liketkit', 'summertime', 'kidsfashion', 'springstyle', 'follow', 'stylishgirls', 'girlsdresses', 'luxury', 'outfitinspiration', 'beach', 'dresses', 'bloggerstyle', 'summervibes', 'igfashion', 'styleoftheday', 'sunglassesaddic', 'fashionstylist', 'snow', 'outfitideas', 'lifestyle', 'boutiquefashion', 'casualstyle', 'highfashion', 'shoptillyoudrop', 'shoes', 'frenzyshopping', 'stylist', 'instadaily', 'whatiweartoday', 'picoftheday', 'instagram', 'jewelry', 'moda', 'menswear', 'travel', 'trending', 'deals', 'accessories', 'vintage', 'shop', 'clothes', 'designer', 'summerstyle', 'cute', 'new', 'streetfashion', 'trend', 'clothing', 'girlsfashion', 'lookbook', 'winteroutfit', 'streetwear', 'buy', 'instashopping', 'fall', 'womenstyle', 'beautiful', 'whatiwore', 'handmade', 'egypt', 'outfitinspo', 'todaysoutfit', 'winterstyle', 'womenfashion', 'dress', 'boutiqueshopping', 'lookoftheday', 'shopsmall', 'beauty', 'instashop', 'photooftheday', 'newarrivals', 'ootdfashion', 'mensfashion', 'womenswear', 'outfit', 'shoplocal', 'styleinspo', 'photography', 'fashionaddict', 'model', 'spring', 'outfitoftheday', 'boutique', 'trendy', 'onlineboutique', 'instastyle', 'sale', 'instagood', 'stylish', 'styleblogger', 'love', 'summer', 'streetstyle', 'onlineshopping', 'womensfashion', 'shopping', 'winter', 'instafashion', 'ootd', 'style', 'fallfashion', 'summerfashion', 'springfashion', 'winterfashion']
# 200

# %%
fashion_dict
# Out:
# [('like', 183),
#  ('instapic', 183),
#  ('hair', 183),
#  ('jewelrygram', 185),
#  ('classy', 185),
#  ('fblogger', 187),
#  ('vintagestyle', 187),
#  ('inspo', 189),
#  ('sexy', 189),
#  ('holiday', 190),
#  ('outfitpost', 190),
#  ('hijabfashion', 190),
#  ('earrings', 190),
#  ('babyfashion', 191),
#  ('fun', 192),
#  ('ss19', 192),
#  ('summerdress', 192),
#  ('photographer', 193),
#  ('jewelrydesign', 193),
#  ('instyle', 194),
#  ('beachwear', 195),
#  ('girls', 195),
#  ('shoppingaddict', 195),
#  ('sun', 195),
#  ('black', 197),
#  ('coat', 198),
#  ('newcollection', 198),
#  ('igstyle', 198),
#  ('bikini', 198),
#  ('menstyle', 202),
#  ('sales', 202),
#  ('modeling', 203),
#  ('me', 206),
#  ('pink', 207),
#  ('fallstyle', 207),
#  ('boho', 208),
#  ('usa', 208),
#  ('men', 209),
#  ('womensclothing', 210),
#  ('plussize', 211),
#  ('sweater', 212),
#  ('shoponline', 212),
#  ('boots', 213),
#  ('shoppingonline', 217),
#  ('ontrend', 217),
#  ('menfashion', 219),
#  ('bohostyle', 220),
#  ('ootn', 224),
#  ('thatsdarling', 225),
#  ('lifestyleblogger', 227),
#  ('floral', 228),
#  ('look', 229),
#  ('swimwear', 230),
#  ('sustainablefashion', 234),
#  ('denim', 236),
#  ('mystyle', 238),
#  ('girlboss', 238),
#  ('selfie', 239),
#  ('art', 239),
#  ('vintagefashion', 242),
#  ('trendsetter', 242),
#  ('jewelryaddict', 242),
#  ('design', 244),
#  ('mensstyle', 246),
#  ('plussizefashion', 246),
#  ('followme', 247),
#  ('women', 247),
#  ('currentlywearing', 248),
#  ('winterwonderland', 250),
#  ('musthave', 253),
#  ('freeshipping', 253),
#  ('cold', 259),
#  ('fitness', 262),
#  ('happy', 268),
#  ('photoshoot', 271),
#  ('instalike', 274),
#  ('outfits', 274),
#  ('trends', 277),
#  ('2019', 278),
#  ('nyc', 279),
#  ('inspiration', 287),
#  ('nature', 288),
#  ('sweaterweather', 291),
#  ('handmadejewelry', 293),
#  ('chic', 297),
#  ('newyork', 298),
#  ('makeup', 299),
#  ('styleinspiration', 300),
#  ('stylegram', 302),
#  ('wiw', 328),
#  ('pretty', 334),
#  ('influencer', 335),
#  ('girl', 337),
#  ('wiwt', 339),
#  ('smallbusiness', 340),
#  ('liketkit', 346),
#  ('summertime', 347),
#  ('kidsfashion', 349),
#  ('springstyle', 349),
#  ('follow', 353),
#  ('stylishgirls', 354),
#  ('girlsdresses', 357),
#  ('luxury', 364),
#  ('outfitinspiration', 366),
#  ('beach', 367),
#  ('dresses', 368),
#  ('bloggerstyle', 375),
#  ('summervibes', 378),
#  ('igfashion', 388),
#  ('styleoftheday', 388),
#  ('sunglassesaddic', 390),
#  ('fashionstylist', 394),
#  ('snow', 396),
#  ('outfitideas', 396),
#  ('lifestyle', 399),
#  ('boutiquefashion', 402),
#  ('casualstyle', 403),
#  ('highfashion', 407),
#  ('shoptillyoudrop', 407),
#  ('shoes', 412),
#  ('frenzyshopping', 419),
#  ('stylist', 422),
#  ('instadaily', 423),
#  ('whatiweartoday', 434),
#  ('picoftheday', 445),
#  ('instagram', 446),
#  ('jewelry', 463),
#  ('moda', 464),
#  ('menswear', 466),
#  ('travel', 471),
#  ('trending', 473),
#  ('deals', 486),
#  ('accessories', 502),
#  ('vintage', 510),
#  ('shop', 511),
#  ('clothes', 513),
#  ('designer', 521),
#  ('summerstyle', 527),
#  ('cute', 530),
#  ('new', 531),
#  ('streetfashion', 535),
#  ('trend', 535),
#  ('clothing', 537),
#  ('girlsfashion', 552),
#  ('lookbook', 557),
#  ('winteroutfit', 559),
#  ('streetwear', 567),
#  ('buy', 577),
#  ('instashopping', 577),
#  ('fall', 586),
#  ('womenstyle', 590),
#  ('beautiful', 602),
#  ('whatiwore', 631),
#  ('handmade', 640),
#  ('egypt', 647),
#  ('outfitinspo', 649),
#  ('todaysoutfit', 653),
#  ('winterstyle', 668),
#  ('womenfashion', 694),
#  ('dress', 727),
#  ('boutiqueshopping', 751),
#  ('lookoftheday', 752),
#  ('shopsmall', 756),
#  ('beauty', 774),
#  ('instashop', 777),
#  ('photooftheday', 792),
#  ('newarrivals', 792),
#  ('ootdfashion', 824),
#  ('mensfashion', 871),
#  ('womenswear', 881),
#  ('outfit', 887),
#  ('shoplocal', 887),
#  ('styleinspo', 889),
#  ('photography', 918),
#  ('fashionaddict', 929),
#  ('model', 948),
#  ('spring', 1059),
#  ('outfitoftheday', 1104),
#  ('boutique', 1122),
#  ('trendy', 1123),
#  ('onlineboutique', 1132),
#  ('instastyle', 1172),
#  ('sale', 1183),
#  ('instagood', 1204),
#  ('stylish', 1323),
#  ('styleblogger', 1336),
#  ('love', 1337),
#  ('summer', 1392),
#  ('streetstyle', 1529),
#  ('onlineshopping', 1568),
#  ('womensfashion', 1592),
#  ('shopping', 1601),
#  ('winter', 1616),
#  ('instafashion', 2587),
#  ('ootd', 4250),
#  ('style', 4389),
#  ('fallfashion', 4400),
#  ('summerfashion', 4822),
#  ('springfashion', 4845),
#  ('winterfashion', 6016)]

# %%
count = 0
for row in tag_df:
    if 'sunglassesaddic' in row:
        count += 1
print(count)
# Out:
# 390

# %% [markdown]
# # Affinity Matrix

# %%
# Affinity Matrix를 만들기 위힌 dataFrame을 만드는 함수입니다.

def get_DataFrame_for_affinity(df,taglist):
    
    result_df = pd.DataFrame(index = np.arange(0,len(df)),columns=taglist)    
    
    zero_list = list()
    for i in range(len(taglist)):
        zero_list.append(0)
    
    i = 0
    for index,row in df.iterrows():
        
        tmp_df = df.loc[index]
        tmp_list = zero_list.copy()
        
        hashlist = tmp_df['hashtags']
        
        for tag in hashlist:
            if tag in taglist:
                tagindex = taglist.index(tag)
                tmp_list[tagindex] = 1
        
        result_df.loc[i] = tmp_list
        i += 1
    
    return result_df

# %%
before_corr = get_DataFrame_for_affinity(fashion_df,tag_list)

# %%
before_corr

# %%
corr_affinity = before_corr.corr(method = 'pearson')

# %%
corr_affinity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, like to winterfashion
# Columns: 200 entries, like to winterfashion
# dtypes: float64(200)
# memory usage: 314.1+ KB

# %%
corr_affinity
# Out:
#                     like  instapic      hair  jewelrygram    classy  fblogger  \
# like            1.000000  0.030419  0.046394    -0.002329 -0.003295  0.011561
# instapic        0.030419  1.000000  0.010178    -0.002728  0.010946  0.008705
# hair            0.046394  0.010178  1.000000    -0.001926 -0.002726 -0.003088
# jewelrygram    -0.002329 -0.002728 -0.001926     1.000000  0.028957 -0.002093
# fblogger             0.036997
# vintagestyle         0.034300
# inspo                0.060422
# sexy                 0.005462
# holiday              0.048283
# outfitpost           0.056859
# hijabfashion         0.021105
# earrings             0.005207
# babyfashion          0.003783
# fun                  0.045208
# ss19                -0.018545
# summerdress         -0.023884
# photographer         0.068683
# jewelrydesign        0.019642
# instyle              0.018281
# beachwear           -0.022909
# girls                0.042431
# shoppingaddict       0.027826
# sun                  0.000435
# black                0.096660
# coat                 0.116339
# newcollection        0.005851
# igstyle              0.042544
# bikini              -0.017027
# menstyle             0.052806
# ...                       ...
# outfit               0.126839
# shoplocal            0.011359
# styleinspo           0.103842
# photography          0.157689
# fashionaddict        0.057608
# model                0.103244
# spring              -0.039937
# outfitoftheday       0.139326
# boutique             0.027640
# trendy               0.053995
# onlineboutique       0.026928
# instastyle           0.094020
# sale                 0.051789
# instagood            0.151932
# stylish              0.077843
# styleblogger         0.136433
# love                 0.151755
# summer              -0.050780
# streetstyle          0.158485
# onlineshopping       0.046747
# womensfashion        0.056178
# shopping             0.065977
# winter               0.486397
# instafashion         0.137849
# ootd                 0.244172
# style                0.194005
# fallfashion         -0.005898
# summerfashion       -0.102337
# springfashion       -0.107038
# winterfashion        1.000000
#
# [200 rows x 200 columns]

# %%
corr_affinity.isnull().sum()
# Out:
# like              1
# instapic          1
# hair              1
# jewelrygram       1
# classy            1
# fblogger          1
# vintagestyle      1
# inspo             1
# sexy              1
# holiday           1
# outfitpost        1
# hijabfashion      1
# earrings          1
# babyfashion       1
# fun               1
# ss19              1
# summerdress       1
# photographer      1
# jewelrydesign     1
# instyle           1
# beachwear         1
# girls             1
# shoppingaddict    1
# sun               1
# black             1
# coat              1
# newcollection     1
# igstyle           1
# bikini            1
# menstyle          1
#                  ..
# outfit            1
# shoplocal         1
# styleinspo        1
# photography       1
# fashionaddict     1
# model             1
# spring            1
# outfitoftheday    1
# boutique          1
# trendy            1
# onlineboutique    1
# instastyle        1
# sale              1
# instagood         1
# stylish           1
# styleblogger      1
# love              1
# summer            1
# streetstyle       1
# onlineshopping    1
# womensfashion     1
# shopping          1
# winter            1
# instafashion      1
# ootd              1
# style             1
# fallfashion       1
# summerfashion     1
# springfashion     1
# winterfashion     1
# Length: 200, dtype: int64

# %%
corr_affinity['like'].sort_values()
# Out:
# shoplocal            -0.007990
# outfitinspo          -0.007664
# casualstyle          -0.006205
# summervibes          -0.005826
# stylist              -0.005764
# wiw                  -0.005356
# kidsfashion          -0.005289
# mystyle              -0.005244
# styleinspiration     -0.005175
# smallbusiness        -0.005152
# boutiquefashion      -0.005105
# boots                -0.005035
# clothing             -0.004717
# bohostyle            -0.004589
# highfashion          -0.004485
# springstyle          -0.004295
# floral               -0.004267
# ootn                 -0.004239
# modeling             -0.004211
# thatsdarling         -0.004068
# sustainablefashion   -0.004068
# boho                 -0.004039
# shoppingonline       -0.003979
# swimwear             -0.003950
# shoponline           -0.003796
# summerdress          -0.003796
# trends               -0.003702
# beachwear            -0.003669
# hijabfashion         -0.003604
# max      1.000000    1.000000    1.000000     1.000000    1.000000
#
#          fblogger  vintagestyle       inspo        sexy     holiday  \
# count  199.000000    199.000000  199.000000  199.000000  199.000000
# mean     0.022172      0.016232    0.021382    0.020289    0.019082
# std      0.075466      0.078049    0.073160    0.072465    0.073013
# min     -0.006944     -0.007211   -0.006146   -0.006781   -0.013016
# 25%     -0.003254     -0.003344   -0.002191   -0.002527   -0.002913
# 50%      0.007436      0.004583    0.011489    0.011580    0.009499
# 75%      0.027552      0.016661    0.025559    0.026639    0.023411
# max      1.000000      1.000000    1.000000    1.000000    1.000000
#
#            ...        womensfashion    shopping      winter  instafashion  \
# count      ...           199.000000  199.000000  199.000000    199.000000
# mean       ...             0.050543    0.051125    0.044364      0.067352
# std        ...             0.083938    0.082076    0.095541      0.088964
# min        ...            -0.013790   -0.009573   -0.065882     -0.007037
# 25%        ...             0.011958    0.010603    0.001272      0.025456
# 50%        ...             0.028047    0.032976    0.021417      0.047107
# 75%        ...             0.066319    0.071573    0.058339      0.083685
# max        ...             1.000000    1.000000    1.000000      1.000000
#
#              ootd       style  fallfashion  summerfashion  springfashion  \
# count  199.000000  199.000000   199.000000     199.000000     199.000000
# mean     0.084111    0.086921     0.063473       0.043603       0.034971
# std      0.096231    0.086901     0.085912       0.092728       0.083235
# min     -0.014059   -0.008553    -0.063174      -0.102337      -0.107038
# 25%      0.034024    0.042027     0.027229       0.012249       0.005537
# 50%      0.061149    0.075830     0.051879       0.028861       0.024845
# 75%      0.109041    0.103096     0.078597       0.045176       0.046966
# max      1.000000    1.000000     1.000000       1.000000       1.000000
#
#        winterfashion
# count     199.000000
# mean        0.062758
# std         0.094632
# min        -0.107038
# 25%         0.019882
# 50%         0.046747
# 75%         0.085565
# max         1.000000
#
# [8 rows x 199 columns]

# %%
corr_affinity_threshold = corr_affinity.copy()

# %%
for tag in tag_list:
    corr_affinity_threshold[tag] = corr_affinity[tag].apply(lambda x: x if x>0.07 else 0)

# %%
corr_affinity_threshold
# Out:
#                     like  instapic      hair  jewelrygram    classy  fblogger  \
# like            1.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# instapic        0.000000  1.000000  0.000000     0.000000  0.000000  0.000000
# hair            0.000000  0.000000  1.000000     0.000000  0.000000  0.000000
# jewelrygram     0.000000  0.000000  0.000000     1.000000  0.000000  0.000000
# classy          0.000000  0.000000  0.000000     0.000000  1.000000  0.000000
# fblogger        0.000000  0.000000  0.000000     0.000000  0.000000  1.000000
# vintagestyle    0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# inspo           0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# sexy            0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# holiday         0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# outfitpost      0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# hijabfashion    0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# earrings        0.000000  0.000000  0.000000     0.153369  0.000000  0.000000
# babyfashion     0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# fun             0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# ss19            0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# summerdress     0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# photographer    0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# jewelrydesign   0.000000  0.000000  0.000000     0.501059  0.000000  0.000000
# instyle         0.000000  0.000000  0.000000     0.141684  0.000000  0.000000
# beachwear       0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# girls           0.083280  0.000000  0.000000     0.000000  0.000000  0.000000
# shoppingaddict  0.000000  0.000000  0.000000     0.159404  0.000000  0.000000
# sun             0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# black           0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# coat            0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# inspo                0.000000
# sexy                 0.000000
# holiday              0.000000
# outfitpost           0.000000
# hijabfashion         0.000000
# earrings             0.000000
# babyfashion          0.000000
# fun                  0.000000
# ss19                 0.000000
# summerdress          0.000000
# photographer         0.000000
# jewelrydesign        0.000000
# instyle              0.000000
# beachwear            0.000000
# girls                0.000000
# shoppingaddict       0.000000
# sun                  0.000000
# black                0.096660
# coat                 0.116339
# newcollection        0.000000
# igstyle              0.000000
# bikini               0.000000
# menstyle             0.000000
# ...                       ...
# outfit               0.126839
# shoplocal            0.000000
# styleinspo           0.103842
# photography          0.157689
# fashionaddict        0.000000
# model                0.103244
# spring               0.000000
# outfitoftheday       0.139326
# boutique             0.000000
# trendy               0.000000
# onlineboutique       0.000000
# instastyle           0.094020
# sale                 0.000000
# instagood            0.151932
# stylish              0.077843
# styleblogger         0.136433
# love                 0.151755
# summer               0.000000
# streetstyle          0.158485
# onlineshopping       0.000000
# womensfashion        0.000000
# shopping             0.000000
# winter               0.486397
# instafashion         0.137849
# ootd                 0.244172
# style                0.194005
# fallfashion          0.000000
# summerfashion        0.000000
# springfashion        0.000000
# winterfashion        1.000000
#
# [199 rows x 199 columns]

# %%
corr_affinity_threshold['winterfashion'].sort_values(ascending = False)
# Out:
# winterfashion       1.000000
# winter              0.486397
# winteroutfit        0.303755
# snow                0.281379
# winterstyle         0.278322
# ootd                0.244172
# winterwonderland    0.225894
# cold                0.222933
# style               0.194005
# photooftheday       0.158927
# streetstyle         0.158485
# photography         0.157689
# ootdfashion         0.157155
# instagood           0.151932
# love                0.151755
# selfie              0.141990
# outfitoftheday      0.139326
# instafashion        0.137849
# styleblogger        0.136433
# picoftheday         0.129326
# outfit              0.126839
# sweaterweather      0.124283
# instagram           0.123990
# outfitinspo         0.121116
# instapic            0.117534
# coat                0.116339
# boots               0.115256
# lifestyle           0.111281
# sweater             0.111091
# mensfashion         0.110316
#                       ...
# new                 0.000000
# freeshipping        0.000000
# spring              0.000000
# fitness             0.000000
# fashionaddict       0.000000
# shoplocal           0.000000
# trends              0.000000
# womenswear          0.000000
# newarrivals         0.000000
# instashop           0.000000
# shopsmall           0.000000
# handmadejewelry     0.000000
# chic                0.000000
# boutiqueshopping    0.000000
# styleinspiration    0.000000
# stylegram           0.000000
# dress               0.000000
# pretty              0.000000
# influencer          0.000000
# womenfashion        0.000000
# smallbusiness       0.000000
# liketkit            0.000000
# summertime          0.000000
# kidsfashion         0.000000
# springstyle         0.000000
# springfashion       0.000000
# stylishgirls        0.000000
# girlsdresses        0.000000
# luxury              0.000000
# like                0.000000
# Name: winterfashion, Length: 199, dtype: float64

# %%
for i in fashion_dict:
    if i[0] == 'sunglassesaddic':
        fashion_dict.remove(i)

# %%
corr_affinity.isnull().sum().any()
# Out:
# False

# %% [markdown]
# # max_values

# %%
max_values = []
for tag in tag_list:
    
    series = corr_affinity[tag].sort_values(ascending = False)
    max_value = [series[1],series[2],series[3],series[4],series[5]]
    max_list = []
    for i in range(5):
        max_list.append(series[series == max_value[i]].index[0])
    max_values.append(max_list)

# %%
print(max_values[0][0])
# Out:
# follow

# %%
len(max_values)
# Out:
# 199

# %%
len(max_values[0])
# Out:
# 5

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import SpectralClustering

# %%
corr_affinity_power = np.power(corr_affinity, 2)
# Spectral clustering에 사용되는 affinity matrix에는 음수가 들어가면 에러...

# %%
pearson_sc = SpectralClustering(n_clusters=15,affinity='precomputed')
# affinity = 'precomputed' 값을 줘야 우리가 주는 인자를 affinity matrix로 사용합니다.

# %%
predict_sc=pearson_sc.fit_predict(corr_affinity_power)

# %%
predict_sc = pd.DataFrame(predict_sc)

# %%
predict_sc.columns = ['predict']

# %%
predict_sc.head()
# Out:
#    predict
# 0        3
# 1        3
# 2        3
# 3       12
# 4        0

# %% [markdown]
# # Build Node

# %%
node_df = pd.DataFrame(fashion_dict, columns=['Tag','Freq'])

# %%
node_df
# Out:
#                 Tag  Freq
# 0              like   183
# 1          instapic   183
# 2              hair   183
# 3       jewelrygram   185
# 4            classy   185
# 5          fblogger   187
# 6      vintagestyle   187
# 7             inspo   189
# 8              sexy   189
# 9           holiday   190
# 10       outfitpost   190
# 11     hijabfashion   190
# 12         earrings   190
# 13      babyfashion   191
# 14              fun   192
# 15             ss19   192
# 16      summerdress   192
# 17     photographer   193
# 18    jewelrydesign   193
# 19          instyle   194
# 20        beachwear   195
# 21            girls   195
# 22   shoppingaddict   195
# 23              sun   195
# 24            black   197
# 25             coat   198
# 26    newcollection   198
# 27          igstyle   198
# 28           bikini   198
# 29         menstyle   202
# ..              ...   ...
# 169          outfit   887
# 170       shoplocal   887
# 171      styleinspo   889
# 172     photography   918
# 173   fashionaddict   929
# 174           model   948
# 175          spring  1059
# 176  outfitoftheday  1104
# 177        boutique  1122
# 178          trendy  1123
# 179  onlineboutique  1132
# 180      instastyle  1172
# 181            sale  1183
# 182       instagood  1204
# 183         stylish  1323
# 184    styleblogger  1336
# 185            love  1337
# 186          summer  1392
# 187     streetstyle  1529
# 188  onlineshopping  1568
# 189   womensfashion  1592
# 190        shopping  1601
# 191          winter  1616
# 192    instafashion  2587
# 193            ootd  4250
# 194           style  4389
# 195     fallfashion  4400
# 196   summerfashion  4822
# 197   springfashion  4845
# 198   winterfashion  6016
#
# [199 rows x 2 columns]

# %%
node_df['Group'] = predict_sc
node_df
# Out:
#                 Tag  Freq  Group
# 0              like   183      3
# 1          instapic   183      3
# 2              hair   183      3
# 3       jewelrygram   185     12
# 4            classy   185      0
# 5          fblogger   187      0
# 6      vintagestyle   187      7
# 7             inspo   189      0
# 8              sexy   189      3
# 9           holiday   190      3
# 10       outfitpost   190      0
# 11     hijabfashion   190     10
# 12         earrings   190     12
# 13      babyfashion   191      2
# 14              fun   192     13
# 15             ss19   192      2
# 16      summerdress   192     13
# 17     photographer   193      3
# 18    jewelrydesign   193     12
# 19          instyle   194     12
# 20        beachwear   195      6
# 21            girls   195      3
# 22   shoppingaddict   195     12
# 23              sun   195     13
# 24            black   197      3
# 25             coat   198      0
# 26    newcollection   198      2
# 27          igstyle   198      0
# 28           bikini   198      6
# 29         menstyle   202      9
# ..              ...   ...    ...
# 169          outfit   887      0
# 170       shoplocal   887      2
# 171      styleinspo   889      0
# 172     photography   918      3
# 173   fashionaddict   929      0
# 174           model   948      3
# 175          spring  1059      2
# 176  outfitoftheday  1104      0
# 177        boutique  1122      2
# 178          trendy  1123      0
# 179  onlineboutique  1132      2
# 180      instastyle  1172      0
# 181            sale  1183      2
# 182       instagood  1204      3
# 183         stylish  1323      0
# 184    styleblogger  1336      0
# 185            love  1337      3
# 186          summer  1392     13
# 187     streetstyle  1529      0
# 188  onlineshopping  1568      2
# 189   womensfashion  1592      2
# 190        shopping  1601      2
# 191          winter  1616     14
# 192    instafashion  2587      0
# 193            ootd  4250      0
# 194           style  4389      0
# 195     fallfashion  4400      0
# 196   summerfashion  4822     13
# 197   springfashion  4845      2
# 198   winterfashion  6016     14
#
# [199 rows x 3 columns]

# %%
group_sort = node_df.sort_values(['Group'],ascending=True)

# %%
group_sort.head()
# Out:
#                Tag  Freq  Group
# 34       fallstyle   207      0
# 76         outfits   274      0
# 173  fashionaddict   929      0
# 93            wiwt   339      0
# 171     styleinspo   889      0

# %%
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
G = nx.Graph(day = "Stackoverflow")

for index,row in group_sort.iterrows():
    G.add_node(row['Tag'], group = row['Group'], nodesize = row['Freq'])
    

#     
for index1,row1 in group_sort.iterrows():
    for index2,row2 in group_sort.iterrows():
        if row1['Tag'] == row2['Tag']:
            continue
        if corr_affinity[row1['Tag']][row2['Tag']] > 0.1:
            G.add_edge(row1['Tag'],row2['Tag'],weight = corr_affinity[row1['Tag']][row2['Tag']]*10)


# # corr_affinity 값이 높은 노드들만 엣지를 연결한다. 1개 ~ 5개 까지 조절 가능
# i = 0
# for index1,row1 in node_df.iterrows():
#     for j in range(5):
#         try:
#             G.add_edge(row1['Tag'],max_values[i][j],weight = corr_affinity[row1['Tag']][max_values[i][j]]*5 )
#         except:
#             print('tag : ' + row1['Tag'] + ' i,j ' + str(i) + ' '+ str(j))
    
#     i += 1

color_map = {1:'#FF0000', 2:'#FF8000', 3:'#AEB404', 4:'#80FF00', 5:'#0B610B', 6:'#0B615E',  
             7:'#6E6E6E', 0:'#0174DF', 8:'#3A01DF', 9:'#5F04B4', 10:'#FF00FF', 11:'#8A0829',
            12:'#8A4B08',13: '#FA8258' ,14:'#5B895A'}
plt.figure(figsize = (30,30))

options = {
    'edge_color': '#FFDEA2',
    'width': 1,
    'with_labels': True,
    'font_weight': 'regular',
}

colors = [color_map[G.node[node]['group']] for node in G]
sizes = [G.node[node]['nodesize']*3 for node in G]

nx.draw(G, node_color=colors, node_size=sizes, pos=nx.spring_layout(G, k=0.1, iterations=10), **options)
ax = plt.gca()
ax.collections[0].set_edgecolor("#555555")
fig = plt.gcf()
plt.show()
fig.savefig('Hash_Network_Graph_image/allseason_notGroupby_groupsort_n15_2m_threshold_affinity_007_01')

# %% [markdown]
# # Clustering Group

# %%
tmp = group_sort[group_sort.Group == 0]

# %%
tags = tmp.Tag

# %%
tags = list(tags)
print(tags)
# Out:
# ['fallstyle', 'outfits', 'fashionaddict', 'wiwt', 'styleinspo', 'whatiwore', 'trends', 'outfit', 'influencer', 'sweater', 'wiw', 'boots', 'liketkit', 'stylegram', 'styleinspiration', 'clothes', 'ootn', 'thatsdarling', 'lifestyleblogger', 'chic', 'look', 'sweaterweather', 'lookoftheday', 'streetfashion', 'mystyle', 'ootdfashion', 'outfitideas', 'todaysoutfit', 'outfitinspo', 'fallfashion', 'style', 'ootd', 'classy', 'fblogger', 'instafashion', 'inspo', 'casualstyle', 'currentlywearing', 'outfitpost', 'styleoftheday', 'streetstyle', 'stylist', 'bloggerstyle', 'streetwear', 'styleblogger', 'stylish', 'outfitinspiration', 'moda', 'instastyle', 'lookbook', 'trendy', 'outfitoftheday', 'coat', 'igstyle', 'trend']

# %%
c_group = list()
for i in range(15):
    tmp = group_sort[group_sort.Group == i]
    tags = list(tmp.Tag)
    c_group.append(tags)

# %%
type(c_group[0])
# Out:
# list

# %%
testarray = np.array(c_group)

# %%
croup = pd.DataFrame(testarray)

# %%
croup
# Out:
#                                                     0
# 0   [fallstyle, outfits, fashionaddict, wiwt, styl...
# 1                         [plussize, plussizefashion]
# 2   [clothing, girlboss, shop, accessories, smallb...
# 3   [picoftheday, instadaily, love, instagood, bea...
# 4                                      [newyork, nyc]
# 5                                   [bohostyle, boho]
# 6                       [swimwear, beachwear, bikini]
# 7             [vintage, vintagefashion, vintagestyle]
# 8                    [whatiweartoday, frenzyshopping]
# 9   [menstyle, mensfashion, menfashion, men, mensw...
# 10  [pretty, hijabfashion, fashionstylist, highfas...
# 11  [egypt, shoptillyoudrop, instashopping, buy, g...
# 12  [trendsetter, igfashion, earrings, jewelrydesi...
# 13  [summertime, summerstyle, summerfashion, beach...
# 14  [snow, winterstyle, winterwonderland, cold, wi...

# %%
croup.columns = ['Tags']

# %%
croup
# Out:
#                                                  Tags
# 0   [fallstyle, outfits, fashionaddict, wiwt, styl...
# 1                         [plussize, plussizefashion]
# 2   [clothing, girlboss, shop, accessories, smallb...
# 3   [picoftheday, instadaily, love, instagood, bea...
# 4                                      [newyork, nyc]
# 5                                   [bohostyle, boho]
# 6                       [swimwear, beachwear, bikini]
# 7             [vintage, vintagefashion, vintagestyle]
# 8                    [whatiweartoday, frenzyshopping]
# 9   [menstyle, mensfashion, menfashion, men, mensw...
# 10  [pretty, hijabfashion, fashionstylist, highfas...
# 11  [egypt, shoptillyoudrop, instashopping, buy, g...
# 12  [trendsetter, igfashion, earrings, jewelrydesi...
# 13  [summertime, summerstyle, summerfashion, beach...
# 14  [snow, winterstyle, winterwonderland, cold, wi...

# %%
a = croup.loc[13]

# %%
b = a['Tags']

# %%
b
# Out:
# ['summertime',
#  'summerstyle',
#  'summerfashion',
#  'beach',
#  'summerdress',
#  'fun',
#  'summer',
#  'summervibes',
#  'sun']
