# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# Input data files check
from subprocess import check_output
print(check_output(["ls", "input_network"]).decode("utf8"))
# Out:
# stack_network_links.csv
# stack_network_nodes.csv

# %%
net_links = pd.read_csv('input_network/stack_network_links.csv')
net_nodes = pd.read_csv('input_network/stack_network_nodes.csv')

# %%
net_links
# Out:
#                source               target      value
# 0               azure                 .net  20.933192
# 1          sql-server                 .net  32.322524
# 2             asp.net                 .net  48.407030
# 3    entity-framework                 .net  24.370903
# 4                 wpf                 .net  32.350925
# 5                linq                 .net  20.501744
# 6                 wcf                 .net  28.074400
# 7                  c#                 .net  62.167895
# 8                 tdd                agile  37.146590
# 9         codeigniter                 ajax  23.191900
# 10             jquery                 ajax  50.566729
# 11              mysql                 ajax  24.800089
# 12                css                 ajax  26.613714
# 13                php                 ajax  28.010679
# 14         javascript                 ajax  24.399144
# 15               json                 ajax  32.947446
# 16              cloud  amazon-web-services  21.318607
# 17              azure  amazon-web-services  21.309950
# 18             devops  amazon-web-services  24.983531
# 19             docker  amazon-web-services  32.198071
# 20                ios              android  39.778036
# 21     android-studio              android  33.661083
# 22               java              android  50.984731
# 23            android       android-studio  33.661083
# 24         typescript              angular  31.036482
# 25         typescript             angular2  38.879982
# 26          angularjs             angular2  26.032697
# 27    ionic-framework            angularjs  29.840446
# 28            reactjs            angularjs  31.620202
# 29            mongodb            angularjs  31.510711
# ..                ...                  ...        ...
# 460                c#                  wcf  29.299880
# 461        sql-server                  wcf  26.291466
# 462               wpf                  wcf  53.179903
# 463              linq                  wcf  34.587093
# 464           asp.net                  wcf  40.951422
# 465   asp.net-web-api                  wcf  28.356535
# 466              rest         web-services  33.690669
# 467         hibernate         web-services  21.210957
# 468            spring         web-services  20.165606
# 469        powershell              windows  20.240691
# 470             linux              windows  29.945401
# 471               osx              windows  20.860247
# 472               php            wordpress  41.037045
# 473             html5            wordpress  22.216441
# 474               css            wordpress  31.264825
# 475       codeigniter            wordpress  25.133131
# 476            drupal            wordpress  24.919296
# 477            jquery            wordpress  28.870171
# 478              linq                  wpf  26.468392
# 479               wcf                  wpf  53.179903
# 480  entity-framework                  wpf  24.228202
# 481                c#                  wpf  38.957492
# 482           asp.net                  wpf  28.159023
# 483              .net                  wpf  32.350925
# 484                c#              xamarin  24.673148
# 485       objective-c                xcode  43.418825
# 486             swift                xcode  48.620335
# 487            iphone                xcode  34.712865
# 488               ios                xcode  46.365091
# 489              json                  xml  42.721668
#
# [490 rows x 3 columns]

# %%
net_nodes.sort_values(by=['nodesize'], ascending = False)
# Out:
#                     name  group  nodesize
# 14            javascript      6    649.16
# 42                  java      8    610.65
# 46                python      1    438.67
# 18                   php      6    361.22
# 1                    css      6    341.17
# 12                    c#      2    321.13
# 0                   html      6    272.45
# 10                   c++      1    268.11
# 41               android      4    229.86
# 15                jquery      6    208.29
# 9                      c      1    189.83
# 19                 mysql      6    165.43
# 94                   sql      2    154.23
# 8                  html5      6    140.18
# 11               asp.net      2    129.55
# 51             angularjs      6    126.59
# 30               node.js      3    117.36
# 64                 linux      5    108.54
# 6                    ios      4     87.46
# 21                  .net      2     75.08
# 4                   ruby      3     70.14
# 28            sql-server      2     64.62
# 7                  swift      4     63.62
# 17               reactjs      3     59.03
# 5          ruby-on-rails      3     55.31
# 34                   git      5     54.48
# 3                 spring      8     52.84
# 89                     r      1     52.70
# 31               mongodb      3     50.95
# 13           objective-c      4     47.01
# ..                   ...    ...       ...
# 101                shell      5     11.63
# 96               eclipse      8     11.39
# 36             excel-vba     14     11.38
# 48                 xcode      4     11.37
# 52       asp.net-web-api      2     11.28
# 106              haskell     10     11.18
# 103              xamarin      2     11.18
# 27          apache-spark     10     11.04
# 105                  mvc      2     10.92
# 87         elasticsearch      3     10.82
# 111                cloud      9     10.66
# 83                    qt      1     10.53
# 54                 plsql      2     10.32
# 61                 maven      8     10.30
# 108  twitter-bootstrap-3      6     10.13
# 77               jenkins      9     10.02
# 113           powershell      5      9.85
# 99                devops      9      9.81
# 24                  less      6      9.73
# 50                 nginx      5      9.49
# 109                regex     13      9.46
# 68                   tdd     12      9.45
# 58                 flask      1      9.39
# 73               testing     11      8.95
# 107                  api      8      8.61
# 16                 redux      3      8.52
# 86       ionic-framework      6      8.44
# 88                vue.js      6      8.38
# 38                  linq      2      8.32
# 100               drupal      6      8.25
#
# [115 rows x 3 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

G = nx.Graph(day="Stackoverflow")
df_nodes = pd.read_csv('input_network/stack_network_nodes.csv')
df_edges = pd.read_csv('input_network/stack_network_links.csv')

for index, row in df_nodes.iterrows():
    G.add_node(row['name'], group=row['group'], nodesize=row['nodesize'])
    
# for index, row in df_edges.iterrows():
#     G.add_weighted_edges_from([(row['source'], row['target'], row['value'])])
    
color_map = {1:'#f09494', 2:'#eebcbc', 3:'#72bbd0', 4:'#91f0a1', 5:'#629fff', 6:'#bcc2f2',  
             7:'#eebcbc', 8:'#f1f0c0', 9:'#d2ffe7', 10:'#caf3a6', 11:'#ffdf55', 12:'#ef77aa', 
             13:'#d6dcff', 14:'#d2f5f0'} 

plt.figure(figsize=(25,25))
options = {
    'edge_color': '#FFDEA2',
    'width': 1,
    'with_labels': True,
    'font_weight': 'regular',
}
colors = [color_map[G.node[node]['group']] for node in G]
sizes = [G.node[node]['nodesize']*10 for node in G]

"""
Using the spring layout : 
- k controls the distance between the nodes and varies between 0 and 1
- iterations is the number of times simulated annealing is run
default k=0.1 and iterations=50
"""
nx.draw(G, node_color=colors, node_size=sizes, pos=nx.spring_layout(G, k=0.25, iterations=50), **options)
ax = plt.gca()
ax.collections[0].set_edgecolor("#555555") 
plt.show()
